# %%
import json
import numpy as np
import pandas as pd
import csv
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.base import clone
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import auc, roc_curve, roc_auc_score
from keras.models import model_from_json

sns.set_style("darkgrid")

# %% [markdown]
# ### We can now use the model to predict comps not played as much with different carries
# We focus on the mock data of knights that we created and recall that Kayle was the main non-knight carry but what about other possible carries like Lucian, Akshan, Karma or Teemo? All of these carry-worthy heroes do not show up (with Garen and Galio) too much in the data (typically single digits)

# %%
mock_data = pd.read_pickle("mock_data_encoded.pkl")

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
mock_data_input = mock_data.iloc[:,:-4]

# %%
list(mock_data_input.columns)
# Out:
# ['Set5_Assassin',
#  'Set5_Brawler',
#  'Set5_Cavalier',
#  'Set5_Forgotten',
#  'Set5_Ironclad',
#  'Set5_Legionnaire',
#  'Set5_Nightbringer',
#  'Set5_Redeemed',
#  'Set5_Sentinel',
#  'Set5_Skirmisher',
#  'Set5_Dawnbringer',
#  'Set5_Invoker',
#  'Set5_Abomination',
#  'Set5_Knight',
#  'Set5_Hellion',
#  'Set5_Ranger',
#  'Set5_Spellweaver',
#  'Set5_Cannoneer',
#  'Set5_Revenant',
#  'Set5_Draconic',
#  'Set5_Mystic',
#  'Set5_Renewer',
#  'Number of Chromatic',
#  'Number of Gold',
#  'Number of Silver',
#  'Number of Bronze',
#  'Synergy Contest_1',
#  'Synergy Contest_2',
#  'Synergy Contest_3',
#  'Vertical Synergies_1',
#  'Vertical Synergies_2',
#  'Primary_Carry_Tier',
#  'Primary_Carry_1',
#  'Primary_Carry_2',
#  'Primary_Carry_3',
#  'Primary_Carry_4',
#  'Primary_Carry_5',
#  'Primary_Carry_6',
#  'Primary_Carry_7',
#  'Primary_Carry_8',
#  'Primary_Carry_9',
#  'Primary_Carry_10',
#  'Primary_Carry_11',
#  'Primary_Carry_12',
#  'Primary_Carry_13',
#  'Primary_Carry_14',
#  'Primary_Carry_15',
#  'Primary_Carry_16',
#  'Primary_Carry_17',
#  'Primary_Carry_18',
#  'Primary_Carry_19',
#  'Primary_Carry_20',
#  'Primary_Carry_21',
#  'Primary_Carry_22',
#  'Primary_Carry_23',
#  'Primary_Carry_24',
#  'Primary_Carry_25',
#  'Primary_Carry_26',
#  'Primary_Carry_27',
#  'Primary_Carry_28',
#  'Primary_Carry_29',
#  'Primary_Carry_30',
#  'Primary_Carry_31',
#  'Primary_Carry_32',
#  'Primary_Carry_33',
#  'Primary_Carry_34',
#  'Primary_Carry_35',
#  'Primary_Carry_36',
#  'Primary_Carry_37',
#  'Primary_Carry_38',
#  'Primary_Carry_39',
#  'Primary_Carry_40',
#  'Primary_Carry_41',
#  'Primary_Carry_42',
#  'Primary_Carry_43',
#  'Primary_Carry_44',
#  'Primary_Carry_45',
#  'Primary_Carry_46',
#  'Primary_Carry_47',
#  'Primary_Carry_48',
#  'Primary_Carry_49',
#  'Primary_Carry_50',
#  'Primary_Carry_51',
#  'Primary_Carry_52',
#  'Primary_Carry_53',
#  'Primary_Carry_54',
#  'Primary_Carry_55',
#  'Primary_Carry_56',
#  'Primary_Carry_57',
#  'Primary_Carry_58',
#  'Secondary_Carry_Tier',
#  'Secondary_Carry_1',
#  'Secondary_Carry_2',
#  'Secondary_Carry_3',
#  'Secondary_Carry_4',
#  'Secondary_Carry_5',
#  'Secondary_Carry_6',
#  'Secondary_Carry_7',
#  'Secondary_Carry_8',
#  'Secondary_Carry_9',
#  'Secondary_Carry_10',
#  'Secondary_Carry_11',
#  'Secondary_Carry_12',
#  'Secondary_Carry_13',
#  'Secondary_Carry_14',
#  'Secondary_Carry_15',
#  'Secondary_Carry_16',
#  'Secondary_Carry_17',
#  'Secondary_Carry_18',
#  'Secondary_Carry_19',
#  'Secondary_Carry_20',
#  'Secondary_Carry_21',
#  'Secondary_Carry_22',
#  'Secondary_Carry_23',
#  'Secondary_Carry_24',
#  'Secondary_Carry_25',
#  'Secondary_Carry_26',
#  'Secondary_Carry_27',
#  'Secondary_Carry_28',
#  'Secondary_Carry_29',
#  'Secondary_Carry_30',
#  'Secondary_Carry_31',
#  'Secondary_Carry_32',
#  'Secondary_Carry_33',
#  'Secondary_Carry_34',
#  'Secondary_Carry_35',
#  'Secondary_Carry_36',
#  'Secondary_Carry_37',
#  'Secondary_Carry_38',
#  'Secondary_Carry_39',
#  'Secondary_Carry_40',
#  'Secondary_Carry_41',
#  'Secondary_Carry_42',
#  'Secondary_Carry_43',
#  'Secondary_Carry_44',
#  'Secondary_Carry_45',
#  'Secondary_Carry_46',
#  'Secondary_Carry_47',
#  'Secondary_Carry_48',
#  'Secondary_Carry_49',
#  'Secondary_Carry_50',
#  'Secondary_Carry_51',
#  'Secondary_Carry_52',
#  'Secondary_Carry_53',
#  'Secondary_Carry_54',
#  'Secondary_Carry_55',
#  'Secondary_Carry_56',
#  'Secondary_Carry_57',
#  'Secondary_Carry_58',
#  'Third_Carry_Tier',
#  'Third_Carry_1',
#  'Third_Carry_2',
#  'Third_Carry_3',
#  'Third_Carry_4',
#  'Third_Carry_5',
#  'Third_Carry_6',
#  'Third_Carry_7',
#  'Third_Carry_8',
#  'Third_Carry_9',
#  'Third_Carry_10',
#  'Third_Carry_11',
#  'Third_Carry_12',
#  'Third_Carry_13',
#  'Third_Carry_14',
#  'Third_Carry_15',
#  'Third_Carry_16',
#  'Third_Carry_17',
#  'Third_Carry_18',
#  'Third_Carry_19',
#  'Third_Carry_20',
#  'Third_Carry_21',
#  'Third_Carry_22',
#  'Third_Carry_23',
#  'Third_Carry_24',
#  'Third_Carry_25',
#  'Third_Carry_26',
#  'Third_Carry_27',
#  'Third_Carry_28',
#  'Third_Carry_29',
#  'Third_Carry_30',
#  'Third_Carry_31',
#  'Third_Carry_32',
#  'Third_Carry_33',
#  'Third_Carry_34',
#  'Third_Carry_35',
#  'Third_Carry_36',
#  'Third_Carry_37',
#  'Third_Carry_38',
#  'Third_Carry_39',
#  'Third_Carry_40',
#  'Third_Carry_41',
#  'Third_Carry_42',
#  'Third_Carry_43',
#  'Third_Carry_44',
#  'Third_Carry_45',
#  'Third_Carry_46',
#  'Third_Carry_47',
#  'Third_Carry_48',
#  'Third_Carry_49',
#  'Third_Carry_50',
#  'Third_Carry_51',
#  'Third_Carry_52',
#  'Third_Carry_53',
#  'Third_Carry_54',
#  'Third_Carry_55',
#  'Third_Carry_56',
#  'Third_Carry_57',
#  'Third_Carry_58',
#  'Carry_Contested_1',
#  'Carry_Contested_2',
#  'Value']

# %%
mock_data_prob = model.predict(np.asarray(mock_data_input[list(mock_data_input.columns)].values).astype('float32'))
mock_top_4_prob = mock_data_prob[:,1]
mock_pred = [np.argmax(x) for x in mock_data_prob]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
mock_data_unencoded = pd.read_pickle("mock_data.pkl")
info = mock_data_unencoded.iloc[:,-12:-6]
info["Top 4 Prediction"] = mock_pred
info["Top 4 Prob"] = mock_top_4_prob

# %%
info[info["Top 4 Prediction"] == 1].sort_values(by = ["Top 4 Prob"], ascending=False)
# Out:
#      Primary_Carry_Tier      Primary_Carry  Secondary_Carry_Tier  \
# 92                    2         TFT5_Garen                     2
# 284                   2         TFT5_Garen                     2
# 140                   2         TFT5_Garen                     2
# 94                    2        TFT5_Akshan                     2
# 86                    2         TFT5_Garen                     2
# 142                   2        TFT5_Akshan                     2
# 80                    2         TFT5_Garen                     1
# 91                    2         TFT5_Galio                     2
# 278                   2         TFT5_Garen                     2
# 68                    1         TFT5_Garen                     2
# 134                   2         TFT5_Garen                     2
# 428                   2         TFT5_Garen                     2
# 272                   2         TFT5_Garen                     1
# 90                    2         TFT5_Galio                     2
# 139                   2         TFT5_Galio                     2
# 382                   2         TFT5_Karma                     2
# 93                    2         TFT5_Garen                     2
# 430                   2         TFT5_Teemo                     2
# 128                   2         TFT5_Garen                     1
# 260                   1         TFT5_Garen                     2
# 88                    2        TFT5_Akshan                     2
# 82                    2        TFT5_Akshan                     1
# 141                   2         TFT5_Garen                     2
# 74                    2         TFT5_Garen                     1
# 138                   2         TFT5_Galio                     2
# 286                   2        TFT5_Draven                     2
# 116                   1         TFT5_Garen                     2
# 136                   2        TFT5_Akshan                     2
# 478                   2        TFT5_Lucian                     2
# 130                   2        TFT5_Akshan                     1
# 62                    1         TFT5_Garen                     2
# 236                   2         TFT5_Garen                     2
# 188                   2         TFT5_Garen                     2
# 56                    1         TFT5_Garen                     1
# 282                   2         TFT5_Galio                     2
# 70                    1        TFT5_Akshan                     2
# 85                    2         TFT5_Galio                     2
# 266                   2         TFT5_Garen                     1
# 118                   1        TFT5_Akshan                     2
# 283                   2         TFT5_Galio                     2
# 422                   2         TFT5_Garen                     2
# 43                    2         TFT5_Galio                     2
# 332                   2         TFT5_Garen                     2
# 331                   2         TFT5_Galio                     2
# 238                   2      TFT5_Aphelios                     2
# 416                   2         TFT5_Garen                     1
# 190                   2      TFT5_Aphelios                     2
# 87                    2         TFT5_Garen                     2
# 370                   2         TFT5_Karma                     1
# 254                   1         TFT5_Garen                     2
# 122                   2         TFT5_Garen                     1
# 376                   2         TFT5_Karma                     2
# 235                   2         TFT5_Galio                     2
# 379                   2         TFT5_Galio                     2
# 133                   2         TFT5_Galio                     2
# 46                    2         TFT5_Kayle                     2
# 67                    1         TFT5_Galio                     2
# 187                   2         TFT5_Galio                     2
# 45                    2         TFT5_Garen                     2
# 79                    2         TFT5_Galio                     1
# 424                   2         TFT5_Teemo                     2
# 95                    2        TFT5_Akshan                     2
# 84                    2         TFT5_Galio                     2
# 143                   2        TFT5_Akshan                     2
# 358                   1         TFT5_Karma                     2
# 285                   2         TFT5_Garen                     2
# 135                   2         TFT5_Garen                     2
# 418                   2         TFT5_Teemo                     1
# 115                   1         TFT5_Galio                     2
# 132                   2         TFT5_Galio                     2
# 127                   2         TFT5_Galio                     1
# 248                   1         TFT5_Garen                     1
# 380                   2         TFT5_Garen                     2
# 189                   2         TFT5_Garen                     2
# 410                   2         TFT5_Garen                     1
# 333                   2         TFT5_Garen                     2
# 426                   2         TFT5_Galio                     2
# 66                    1         TFT5_Galio                     2
# 237                   2         TFT5_Garen                     2
# 78                    2         TFT5_Galio                     1
# 364                   2         TFT5_Karma                     1
# 404                   1         TFT5_Garen                     2
# 381                   2         TFT5_Garen                     2
# 334                   2  TFT5_Heimerdinger                     2
# 81                    2         TFT5_Garen                     1
# 110                   1         TFT5_Garen                     2
# 44                    2         TFT5_Garen                     2
# 76                    2        TFT5_Akshan                     1
# 114                   1         TFT5_Galio                     2
# 406                   1         TFT5_Teemo                     2
# 69                    1         TFT5_Garen                     2
# 182                   2         TFT5_Garen                     2
# 230                   2         TFT5_Garen                     2
# 276                   2         TFT5_Galio                     2
# 104                   1         TFT5_Garen                     1
# 346                   1         TFT5_Karma                     1
# 42                    2         TFT5_Galio                     2
# 352                   1         TFT5_Karma                     2
# 126                   2         TFT5_Galio                     1
# 124                   2        TFT5_Akshan                     1
# 476                   2         TFT5_Garen                     2
# 280                   2        TFT5_Draven                     2
# 274                   2        TFT5_Draven                     1
# 466                   2        TFT5_Lucian                     1
# 129                   2         TFT5_Garen                     1
# 412                   2         TFT5_Teemo                     1
# 176                   2         TFT5_Garen                     1
# 117                   1         TFT5_Garen                     2
# 258                   1         TFT5_Galio                     2
# 50                    1         TFT5_Garen                     1
# 234                   2         TFT5_Galio                     2
# 186                   2         TFT5_Galio                     2
# 392                   1         TFT5_Garen                     1
# 224                   2         TFT5_Garen                     1
# 398                   1         TFT5_Garen                     2
# 454                   1        TFT5_Lucian                     2
# 277                   2         TFT5_Galio                     2
# 427                   2         TFT5_Galio                     2
# 383                   2         TFT5_Karma                     2
# 325                   2         TFT5_Galio                     2
# 106                   1        TFT5_Akshan                     1
# 259                   1         TFT5_Galio                     2
# 39                    2         TFT5_Garen                     2
# 137                   2        TFT5_Akshan                     2
# 326                   2         TFT5_Garen                     2
# 89                    2        TFT5_Akshan                     2
# 19                    1         TFT5_Galio                     2
# 340                   1         TFT5_Karma                     1
# 232                   2      TFT5_Aphelios                     2
# 271                   2         TFT5_Galio                     1
# 37                    2         TFT5_Galio                     2
# 229                   2         TFT5_Galio                     2
# 184                   2      TFT5_Aphelios                     2
# 386                   1         TFT5_Garen                     1
# 226                   2      TFT5_Aphelios                     1
# 429                   2         TFT5_Garen                     2
# 373                   2         TFT5_Galio                     2
# 31                    2         TFT5_Galio                     1
# 178                   2      TFT5_Aphelios                     1
# 279                   2         TFT5_Garen                     2
# 47                    2         TFT5_Kayle                     2
# 112                   1        TFT5_Akshan                     2
# 270                   2         TFT5_Galio                     1
#
#        Secondary_Carry  Third_Carry_Tier        Third_Carry  Top 4 Prediction  \
# 92          TFT5_Galio                 2        TFT5_Akshan                 1
# 284         TFT5_Galio                 2        TFT5_Draven                 1
# 140         TFT5_Galio                 2        TFT5_Akshan                 1
# 94          TFT5_Galio                 2         TFT5_Garen                 1
# 86          TFT5_Galio                 1        TFT5_Akshan                 1
# 142         TFT5_Galio                 2         TFT5_Garen                 1
# 80          TFT5_Galio                 2        TFT5_Akshan                 1
# 91         TFT5_Akshan                 2         TFT5_Garen                 1
# 278         TFT5_Galio                 1        TFT5_Draven                 1
# 68          TFT5_Galio                 2        TFT5_Akshan                 1
# 134         TFT5_Galio                 1        TFT5_Akshan                 1
# 428         TFT5_Galio                 2         TFT5_Teemo                 1
# 272         TFT5_Galio                 2        TFT5_Draven                 1
# 90          TFT5_Garen                 2        TFT5_Akshan                 1
# 139        TFT5_Akshan                 2         TFT5_Garen                 1
# 382         TFT5_Galio                 2         TFT5_Garen                 1
# 93         TFT5_Akshan                 2         TFT5_Galio                 1
# 430         TFT5_Galio                 2         TFT5_Garen                 1
# 128         TFT5_Galio                 2        TFT5_Akshan                 1
# 260         TFT5_Galio                 2        TFT5_Draven                 1
# 88          TFT5_Galio                 1         TFT5_Garen                 1
# 82          TFT5_Galio                 2         TFT5_Garen                 1
# 141        TFT5_Akshan                 2         TFT5_Galio                 1
# 74          TFT5_Galio                 1        TFT5_Akshan                 1
# 138         TFT5_Garen                 2        TFT5_Akshan                 1
# 286         TFT5_Galio                 2         TFT5_Garen                 1
# 116         TFT5_Galio                 2        TFT5_Akshan                 1
# 136         TFT5_Galio                 1         TFT5_Garen                 1
# 478         TFT5_Galio                 2         TFT5_Garen                 1
# 130         TFT5_Galio                 2         TFT5_Garen                 1
# 62          TFT5_Galio                 1        TFT5_Akshan                 1
# 236         TFT5_Galio                 2      TFT5_Aphelios                 1
# 188         TFT5_Galio                 2      TFT5_Aphelios                 1
# 56          TFT5_Galio                 2        TFT5_Akshan                 1
# 282         TFT5_Garen                 2        TFT5_Draven                 1
# 70          TFT5_Galio                 2         TFT5_Garen                 1
# 85         TFT5_Akshan                 1         TFT5_Garen                 1
# 266         TFT5_Galio                 1        TFT5_Draven                 1
# 118         TFT5_Galio                 2         TFT5_Garen                 1
# 283        TFT5_Draven                 2         TFT5_Garen                 1
# 422         TFT5_Galio                 1         TFT5_Teemo                 1
# 43          TFT5_Kayle                 2         TFT5_Garen                 1
# 332         TFT5_Galio                 2  TFT5_Heimerdinger                 1
# 331  TFT5_Heimerdinger                 2         TFT5_Garen                 1
# 238         TFT5_Galio                 2         TFT5_Garen                 1
# 416         TFT5_Galio                 2         TFT5_Teemo                 1
# 190         TFT5_Galio                 2         TFT5_Garen                 1
# 87         TFT5_Akshan                 1         TFT5_Galio                 1
# 370         TFT5_Galio                 2         TFT5_Garen                 1
# 254         TFT5_Galio                 1        TFT5_Draven                 1
# 122         TFT5_Galio                 1        TFT5_Akshan                 1
# 376         TFT5_Galio                 1         TFT5_Garen                 1
# 235      TFT5_Aphelios                 2         TFT5_Garen                 1
# 379         TFT5_Karma                 2         TFT5_Garen                 1
# 133        TFT5_Akshan                 1         TFT5_Garen                 1
# 46          TFT5_Galio                 2         TFT5_Garen                 1
# 67         TFT5_Akshan                 2         TFT5_Garen                 1
# 187      TFT5_Aphelios                 2         TFT5_Garen                 1
# 45          TFT5_Kayle                 2         TFT5_Galio                 1
# 79         TFT5_Akshan                 2         TFT5_Garen                 1
# 424         TFT5_Galio                 1         TFT5_Garen                 1
# 95          TFT5_Garen                 2         TFT5_Galio                 1
# 84          TFT5_Garen                 1        TFT5_Akshan                 1
# 143         TFT5_Garen                 2         TFT5_Galio                 1
# 358         TFT5_Galio                 2         TFT5_Garen                 1
# 285        TFT5_Draven                 2         TFT5_Galio                 1
# 135        TFT5_Akshan                 1         TFT5_Galio                 1
# 418         TFT5_Galio                 2         TFT5_Garen                 1
# 115        TFT5_Akshan                 2         TFT5_Garen                 1
# 132         TFT5_Garen                 1        TFT5_Akshan                 1
# 127        TFT5_Akshan                 2         TFT5_Garen                 1
# 248         TFT5_Galio                 2        TFT5_Draven                 1
# 380         TFT5_Galio                 2         TFT5_Karma                 1
# 189      TFT5_Aphelios                 2         TFT5_Galio                 1
# 410         TFT5_Galio                 1         TFT5_Teemo                 1
# 333  TFT5_Heimerdinger                 2         TFT5_Galio                 1
# 426         TFT5_Garen                 2         TFT5_Teemo                 1
# 66          TFT5_Garen                 2        TFT5_Akshan                 1
# 237      TFT5_Aphelios                 2         TFT5_Galio                 1
# 78          TFT5_Garen                 2        TFT5_Akshan                 1
# 364         TFT5_Galio                 1         TFT5_Garen                 1
# 404         TFT5_Galio                 2         TFT5_Teemo                 1
# 381         TFT5_Karma                 2         TFT5_Galio                 1
# 334         TFT5_Galio                 2         TFT5_Garen                 1
# 81         TFT5_Akshan                 2         TFT5_Galio                 1
# 110         TFT5_Galio                 1        TFT5_Akshan                 1
# 44          TFT5_Galio                 2         TFT5_Kayle                 1
# 76          TFT5_Galio                 1         TFT5_Garen                 1
# 114         TFT5_Garen                 2        TFT5_Akshan                 1
# 406         TFT5_Galio                 2         TFT5_Garen                 1
# 69         TFT5_Akshan                 2         TFT5_Galio                 1
# 182         TFT5_Galio                 1      TFT5_Aphelios                 1
# 230         TFT5_Galio                 1      TFT5_Aphelios                 1
# 276         TFT5_Garen                 1        TFT5_Draven                 1
# 104         TFT5_Galio                 2        TFT5_Akshan                 1
# 346         TFT5_Galio                 2         TFT5_Garen                 1
# 42          TFT5_Garen                 2         TFT5_Kayle                 1
# 352         TFT5_Galio                 1         TFT5_Garen                 1
# 126         TFT5_Garen                 2        TFT5_Akshan                 1
# 124         TFT5_Galio                 1         TFT5_Garen                 1
# 476         TFT5_Galio                 2        TFT5_Lucian                 1
# 280         TFT5_Galio                 1         TFT5_Garen                 1
# 274         TFT5_Galio                 2         TFT5_Garen                 1
# 466         TFT5_Galio                 2         TFT5_Garen                 1
# 129        TFT5_Akshan                 2         TFT5_Galio                 1
# 412         TFT5_Galio                 1         TFT5_Garen                 1
# 176         TFT5_Galio                 2      TFT5_Aphelios                 1
# 117        TFT5_Akshan                 2         TFT5_Galio                 1
# 258         TFT5_Garen                 2        TFT5_Draven                 1
# 50          TFT5_Galio                 1        TFT5_Akshan                 1
# 234         TFT5_Garen                 2      TFT5_Aphelios                 1
# 186         TFT5_Garen                 2      TFT5_Aphelios                 1
# 392         TFT5_Galio                 2         TFT5_Teemo                 1
# 224         TFT5_Galio                 2      TFT5_Aphelios                 1
# 398         TFT5_Galio                 1         TFT5_Teemo                 1
# 454         TFT5_Galio                 2         TFT5_Garen                 1
# 277        TFT5_Draven                 1         TFT5_Garen                 1
# 427         TFT5_Teemo                 2         TFT5_Garen                 1
# 383         TFT5_Garen                 2         TFT5_Galio                 1
# 325  TFT5_Heimerdinger                 1         TFT5_Garen                 1
# 106         TFT5_Galio                 2         TFT5_Garen                 1
# 259        TFT5_Draven                 2         TFT5_Garen                 1
# 39          TFT5_Kayle                 1         TFT5_Galio                 1
# 137         TFT5_Garen                 1         TFT5_Galio                 1
# 326         TFT5_Galio                 1  TFT5_Heimerdinger                 1
# 89          TFT5_Garen                 1         TFT5_Galio                 1
# 19          TFT5_Kayle                 2         TFT5_Garen                 1
# 340         TFT5_Galio                 1         TFT5_Garen                 1
# 232         TFT5_Galio                 1         TFT5_Garen                 1
# 271        TFT5_Draven                 2         TFT5_Garen                 1
# 37          TFT5_Kayle                 1         TFT5_Garen                 1
# 229      TFT5_Aphelios                 1         TFT5_Garen                 1
# 184         TFT5_Galio                 1         TFT5_Garen                 1
# 386         TFT5_Galio                 1         TFT5_Teemo                 1
# 226         TFT5_Galio                 2         TFT5_Garen                 1
# 429         TFT5_Teemo                 2         TFT5_Galio                 1
# 373         TFT5_Karma                 1         TFT5_Garen                 1
# 31          TFT5_Kayle                 2         TFT5_Garen                 1
# 178         TFT5_Galio                 2         TFT5_Garen                 1
# 279        TFT5_Draven                 1         TFT5_Galio                 1
# 47          TFT5_Garen                 2         TFT5_Galio                 1
# 112         TFT5_Galio                 1         TFT5_Garen                 1
# 270         TFT5_Garen                 2        TFT5_Draven                 1
#
#      Top 4 Prob
# 92     0.986968
# 284    0.973054
# 140    0.972569
# 94     0.969723
# 86     0.958452
# 142    0.958105
# 80     0.955775
# 91     0.948015
# 278    0.941184
# 68     0.932067
# 134    0.930314
# 428    0.929863
# 272    0.925803
# 90     0.924834
# 139    0.923928
# 382    0.923765
# 93     0.919077
# 430    0.918369
# 128    0.917621
# 260    0.905546
# 88     0.900007
# 82     0.890116
# 141    0.887130
# 74     0.885498
# 138    0.884572
# 286    0.875017
# 116    0.873465
# 136    0.862533
# 478    0.862466
# 130    0.860562
# 62     0.859358
# 236    0.851588
# 188    0.851023
# 56     0.850262
# 282    0.848086
# 70     0.828317
# 85     0.828274
# 266    0.825950
# 118    0.824200
# 283    0.823698
# 422    0.819113
# 43     0.817010
# 332    0.809956
# 331    0.809896
# 238    0.809600
# 416    0.806946
# 190    0.806677
# 87     0.806526
# 370    0.804703
# 254    0.803399
# 122    0.798084
# 376    0.797625
# 235    0.796722
# 379    0.795473
# 133    0.792757
# 46     0.792743
# 67     0.789475
# 187    0.782763
# 45     0.782233
# 79     0.779698
# 424    0.768577
# 95     0.766252
# 84     0.764758
# 143    0.757868
# 358    0.756059
# 285    0.752673
# 135    0.745307
# 418    0.741446
# 115    0.738458
# 132    0.728022
# 127    0.723611
# 248    0.723155
# 380    0.722729
# 189    0.721749
# 410    0.721480
# 333    0.718419
# 426    0.714850
# 66     0.713883
# 237    0.711221
# 78     0.710392
# 364    0.710233
# 404    0.702600
# 381    0.701625
# 334    0.701050
# 81     0.699065
# 110    0.692058
# 44     0.690539
# 76     0.686078
# 114    0.674203
# 406    0.673202
# 69     0.665890
# 182    0.665852
# 230    0.662791
# 276    0.662607
# 104    0.661121
# 346    0.649316
# 42     0.647430
# 352    0.643503
# 126    0.637800
# 124    0.632189
# 476    0.631721
# 280    0.625745
# 274    0.621211
# 466    0.619708
# 129    0.613674
# 412    0.598616
# 176    0.589658
# 117    0.588392
# 258    0.587602
# 50     0.585764
# 234    0.581817
# 186    0.580701
# 392    0.579191
# 224    0.573605
# 398    0.573253
# 454    0.568783
# 277    0.567650
# 427    0.554789
# 383    0.553449
# 325    0.549223
# 106    0.547194
# 259    0.540146
# 39     0.539862
# 137    0.539258
# 326    0.533672
# 89     0.533665
# 19     0.531696
# 340    0.528866
# 232    0.527683
# 271    0.527507
# 37     0.527263
# 229    0.525967
# 184    0.522984
# 386    0.521853
# 226    0.521378
# 429    0.521054
# 373    0.519796
# 31     0.517383
# 178    0.516672
# 279    0.513303
# 47     0.510686
# 112    0.506404
# 270    0.502498
